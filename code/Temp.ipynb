# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/TripleA/Desktop/coding related/python/TISS/1_MONTH.csv' , encoding='unicode_escape')

# %%
df.dropna(inplace=True)
df.head()
# Out:
#          Date & Time  Temp - °C  High Temp - °C  Low Temp - °C  Hum - %  \
# 89   09-01-2023 7:25       28.0            28.0           28.0     83.0
# 106  09-01-2023 8:50       29.0            29.0           29.0     79.0
# 107  09-01-2023 8:55       29.0            29.0           29.0     78.0
# 108  09-01-2023 9:00       30.0            30.0           29.0     77.0
# 109  09-01-2023 9:05       30.0            30.0           29.0     76.0
#
#      High Hum - %  Low Hum - %  Heat Index - °C  High Heat Index - °C  \
# 89           83.0         83.0             32.0                  32.0
# 106          79.0         79.0             35.0                  35.0
# 107          79.0         78.0             35.0                  35.0
# 108          78.0         77.0             36.0                  36.0
# 109          77.0         76.0             36.0                  36.0
#
#      Rain - in  High Rain Rate - in-h  Solar Rad - W-m^2  \
# ...

# %%
df.dtypes
# Out:
# Date & Time                object
# Temp - °C                 float64
# High Temp - °C            float64
# Low Temp - °C             float64
# Hum - %                   float64
# High Hum - %              float64
# Low Hum - %               float64
# Heat Index - °C           float64
# High Heat Index - °C      float64
# Rain - in                 float64
# High Rain Rate - in-h     float64
# Solar Rad - W-m^2         float64
# High Solar Rad - W-m^2    float64
# dtype: object

# %%
df['Date & Time'] = pd.to_datetime(df['Date & Time'] , format= 'mixed')

# %%
df.dtypes
# Out:
# Date & Time               datetime64[ns]
# Temp - °C                        float64
# High Temp - °C                   float64
# Low Temp - °C                    float64
# Hum - %                          float64
# High Hum - %                     float64
# Low Hum - %                      float64
# Heat Index - °C                  float64
# High Heat Index - °C             float64
# Rain - in                        float64
# High Rain Rate - in-h            float64
# Solar Rad - W-m^2                float64
# High Solar Rad - W-m^2           float64
# dtype: object

# %%
df.set_index('Date & Time',inplace=True)

# %% [markdown]
# TEMPERATURE

# %% [markdown]
#          PER WEEK

# %%
per_week = df[['Temp - °C','High Temp - °C', 'Low Temp - °C']].resample('W')

# %%
plt.plot(per_week['High Temp - °C'].max(),'.-', label = 'MAX')
plt.plot(per_week['Temp - °C'].mean(),'.-', label = 'AVG')
plt.plot(per_week['Low Temp - °C'].min(),'.-', label = 'MIN')
plt.xticks(rotation=45)
plt.ylabel('Temp in °C ')
plt.title('Temperature per week')
plt.grid(True)
plt.legend()
plt.gcf().autofmt_xdate()

# %% [markdown]
#           PER DAY

# %%
per_day = df[['Temp - °C','High Temp - °C', 'Low Temp - °C']].resample('D')

# %%
plt.plot(per_day['Temp - °C'].mean(),'.-', label = 'AVG')
plt.plot(per_day['High Temp - °C'].max(),'.-', label = 'MAX')
plt.plot(per_day['Low Temp - °C'].min(),'.-', label = 'MIN')
plt.xticks(rotation=45)
plt.ylabel('Temp in °C ')
plt.title('Temperature per day')
plt.grid(True)
plt.legend()

# %% [markdown]
# PER HOUR

# %% [markdown]
#         DAY28(Highest Maximum temp)

# %%
day28 = df['2023-09-28 00:00:00':'2023-09-28 23:55:00']

# %%
day28 = day28.resample('h')

# %%
plt.plot(day28['High Temp - °C'].max(),'.-', label = 'MAX')
plt.plot(day28['Temp - °C'].mean(),'.-', label = 'AVG')
plt.plot(day28['Low Temp - °C'].min(),'.-', label = 'MIN')
plt.xticks(rotation=45)
plt.ylabel('Temp in °C ')
plt.title('For 28 November')
plt.grid(True)
plt.legend()
